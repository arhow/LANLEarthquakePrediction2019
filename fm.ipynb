# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler, MinMaxScaler
import lightgbm as lgb
import catboost as cb

from tsfresh.examples import load_robot_execution_failures
from tsfresh import extract_features, select_features
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression, Ridge, Lasso
from fastFM import als, mcmc, sgd
from pyfm import pylibfm

import optuna

from common import EP

import types
# Out:
# Using TensorFlow backend.

# %%
# %%HTML
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df_train = pd.read_pickle('../feats/df_train.pkl')
df_test = pd.read_pickle('../feats/df_test.pkl')

# %%
df_train['label'] = df_train['y'].apply(lambda x:  int(x) if x<15 else 15)
group = df_train['season'].values
group[np.where(group==17)[0]] = 1
df_train['group'] = group
df_train = df_train.drop(columns=['season'])

# %%
test_X = df_train.drop(columns=['y','index','group','label']).copy()
test_X.index = df_train['index']
test_y = df_train['y'].copy()
test_y.index = df_train['index']
tsfresh_columns = select_features(test_X, test_y).columns.tolist()

# %%
original_columns = df_train.columns.drop(['index','y','label','group']).tolist()

# %%
# mytrial = []
mytrial = list(pd.read_pickle('../trial/fm.pkl').T.to_dict().values())
df_trial = pd.DataFrame(mytrial)
len(mytrial)
# Out:
# 10

# %%
param = {'algorithm': {'cls': 'als.FMRegression',
  'fit': {},
  'init': {'n_iter': 50,
   'init_stdev': 0.01,
   'rank': 6,
   'random_state': 42,
   'l2_reg_w': 0.1,
   'l2_reg_V': 0.1,
   'l2_reg': 0}},
 'columns': ["change_quantiles{'ql': 0.4, 'qh': 0.8, 'isabs': False, 'f_agg': 'var'}",
  'spkt_welch_density__coeff_65',
  'q05_roll_std_10',
  'Hilbert_mean_2',
  'min__roll_std',
  'spkt_welch_density__coeff_4',
  'abs_max_6',
  'spkt_welch_density__coeff_99',
  'abs_q01_7',
  'abs_max_8',
  'kurt_7',
  'partial_autocorrelationlag_5',
  'q05_2',
  'abs_max_roll_mean_100',
  'spkt_welch_density__coeff_50',
  'abs_q01_6',
  'ave10_6',
  "binned_entropy{'max_bins': 10}",
  'min_roll_std_100',
  'spkt_welch_density__coeff_113',
  'med_6',
  'spkt_welch_density__coeff_42',
  '4th_peak_psd',
  '5000min_quantile05',
  'fft_coefficientcoeff_36__attr_"abs"',
  'spkt_welch_density__coeff_41',
  'q01_roll_std_100',
  'max_to_min',
  'spkt_welch_density__coeff_17',
  'abs_min_5',
  'q25_roll_std_100',
  '5000skewness_mean_',
  "change_quantiles{'ql': 0.2, 'qh': 0.4, 'isabs': True, 'f_agg': 'mean'}",
  'peak_to_average_power_ratio__roll_mean',
  'fft_coefficientcoeff_20__attr_"abs"',
  'fft_coefficientcoeff_50__attr_"abs"',
  "change_quantiles{'ql': 0.2, 'qh': 1.0, 'isabs': False, 'f_agg': 'mean'}",
  'q01_roll_std_1000',
  'abs_max_5',
  'FFT_Mag_25q0',
  'abs_q95_7',
  '5000skewness_max_',
  '5000std_quantile05',
  'abs_q25_5',
  "number_peaks{'n': 3}",
  'q05_roll_std_1000',
  'abs_q99_7',
  'abs_q95_2',
  'q75_roll_std_10',
  'spkt_welch_density__coeff_84',
  'abs_q75_6',
  'abs_max_3',
  'kurt_3',
  "change_quantiles{'ql': 0.4, 'qh': 0.6, 'isabs': False, 'f_agg': 'mean'}",
  'iqr',
  'spkt_welch_density__coeff_64',
  'fft_coefficientcoeff_8__attr_"imag"',
  'spkt_welch_density__coeff_29',
  'iqr_6',
  "autocorrelation{'lag': 5}",
  'spkt_welch_density__coeff_57',
  'spkt_welch_density__coeff_117',
  'q25_1',
  "number_crossing_m{'m': 1}",
  'fft_coefficientcoeff_32__attr_"imag"',
  'fft_coefficientcoeff_21__attr_"abs"',
  'abs_q95_6',
  'Hilbert_mean_1',
  'skew_1',
  'iqr_9',
  'ave10_2',
  'median__roll_std',
  '5000clearance_factor_quantile25',
  'abs_q95_8',
  '5000smoothness_quantile05',
  'med_4',
  'spkt_welch_density__coeff_28',
  'abs_max_roll_mean_1000',
  '5000kurtosis_mean_',
  'iqr_8',
  '5000kurtosis_quantile75',
  'spkt_welch_density__coeff_31',
  'med_5',
  'min__roll_mean',
  'abs_q01_4',
  'fft_coefficientcoeff_24__attr_"imag"',
  'max_to_min_6',
  'abs_q75_2',
  'q05_5',
  'spkt_welch_density__coeff_25',
  'q05_roll_std_100',
  'abs_q75_7',
  'abs_q01_5',
  'FFT_Mag_75q0',
  'mean_change_rate',
  'med_8',
  'q01_roll_std_10',
  'fft_coefficientcoeff_56__attr_"angle"',
  '3th_peak_freq',
  'abs_q05_9',
  'abs_min_3',
  '5000smoothness_std_',
  'fft_coefficientcoeff_24__attr_"real"',
  'abs_q05_7',
  'q99_roll_mean_1000',
  'abs_q99_8',
  '5000rms_quantile25',
  'abs_max_7',
  "change_quantiles{'ql': 0.2, 'qh': 0.8, 'isabs': False, 'f_agg': 'var'}",
  'q95_roll_mean_1000',
  '5000quantile25peak_to_average_power_ratio_',
  "number_peaks{'n': 10}",
  'abs_q05_6',
  'spkt_welch_density__coeff_3',
  'spkt_welch_density__coeff_38',
  'spkt_welch_density__coeff_115',
  'abs_q25_9',
  'fft_coefficientcoeff_62__attr_"abs"',
  'max_to_min_diff_5',
  'abs_q05_2',
  'fft_coefficientcoeff_80__attr_"imag"',
  "number_peaks{'n': 5}",
  "autocorrelation{'lag': 4}",
  'abs_min_2',
  'FFT_Mag_95q0',
  'spkt_welch_densitycoeff_8',
  'abs_q05_1',
  'min_9',
  "change_quantiles{'ql': 0.0, 'qh': 0.8, 'isabs': False, 'f_agg': 'mean'}",
  "number_peaks{'n': 1}",
  'partial_autocorrelationlag_1',
  'q01_roll_mean_1000',
  'abs_max_1',
  'max_to_min_1',
  'abs_min_6',
  'abs_min_7',
  'fft_coefficientcoeff_19__attr_"abs"',
  "value_count{'value': 1}",
  'abs_q25_7',
  "change_quantiles{'ql': 0.6, 'qh': 0.8, 'isabs': True, 'f_agg': 'mean'}",
  'MA_1000MA_std_mean_7',
  "value_count{'value': -1}",
  'abs_q25_1',
  'spkt_welch_density__coeff_79',
  'agg_autocorrelationf_agg_"mean"__maxlag_40',
  'max_to_min_5',
  'q95_9',
  'spkt_welch_densitycoeff_2',
  '5000peak_peak_amp_max_',
  'fft_coefficientcoeff_16__attr_"imag"',
  '5000form_factor_quantile75',
  'fft_coefficientcoeff_26__attr_"abs"',
  'spkt_welch_density__coeff_63',
  'med_2',
  '5000std_quantile25',
  'max_9',
  'fft_coefficientcoeff_6__attr_"abs"',
  'spkt_welch_density__coeff_30',
  '5000smoothness_entropy_',
  'abs_max_2',
  'abs_max_4',
  '5000quantile05median_',
  'ave10_7',
  'abs_q25_8',
  'abs_q75_1'],
 'kfold': {'n_splits': 3,
  'random_state': 1985,
  'shuffle': True,
  'type': 'group'},
 'scaler': {'cls': 'StandardScaler'}}

# %%
# run one try
df_his,  df_feature_importances, df_valid_pred, df_test_pred =  EP.process(df_train, param, df_test = df_test, trial=mytrial)

# %%
als.FMRegression?

# %%
#  tune hypterparameters
def objective(trial):

    n_iter = trial.suggest_int('n_iter', 10, 100)
    init_stdev = trial.suggest_uniform('init_stdev', 0.00001, .01)
    rank = trial.suggest_int('rank', 2, 16)
        
    args={'algorithm': {'cls': 'als.FMRegression',
      'fit': {},
      'init': {'n_iter': n_iter,
       'init_stdev': init_stdev,
       'rank': rank,
       'random_state': 42,
       'l2_reg_w': 0.1,
       'l2_reg_V': 0.1,
       'l2_reg': 0}},
     'columns': param['columns'].copy(),
     'kfold': {'n_splits': 3,
      'random_state': 1985,
      'shuffle': True,
      'type': 'group'},
     'scaler': {'cls': 'StandardScaler'}}
    
    df_his,  df_feature_importances, df_valid_pred, df_test_pred =  EP.process(df_train, args, df_test = df_test, trial=mytrial, remark='tune 11')
    val_mae_mean = np.mean(df_his.valid)
    val_mae_var = np.var(df_his.valid)
    train_mae_mean = np.mean(df_his.train)
    train_mae_var = np.var(df_his.train)
    
    trial.set_user_attr('val_mae', val_mae_mean)
    trial.set_user_attr('train_mae', train_mae_mean)
    trial.set_user_attr('mae_diff', val_mae_mean-train_mae_mean)
    trial.set_user_attr('val_mae_var', val_mae_var)

    return np.abs(val_mae_mean - train_mae_mean)*val_mae_mean

study = optuna.create_study()
study.optimize(objective, n_trials=100)
# Out:
# [I 2019-05-17 02:08:06,859] Finished a trial resulted in value: 1.1128082411819047. Current best value is 1.1128082411819047 with parameters: {'n_iter': 18, 'init_stdev': 0.0003839582549693036, 'rank': 13}.
# 141  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 142  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 143  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 144  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 145  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 146  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 147  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 148  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 149  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 150  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 151  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 152  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 153  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 154  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 155  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 156  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 157  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 158  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 159  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 160  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 139  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 161  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 138  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 136  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 115  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 116  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 117  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 118  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# ..                                                                                                                ...
# 109  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 110  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 89   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 88   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 87   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 86   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 64   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 65   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 66   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 67   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 68   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 69   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 70   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 71   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 72   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 73   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 211  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 74   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 76   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 77   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 78   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 79   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 80   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 81   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 82   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 83   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 84   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 85   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 75   {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
# 212  {'n_iter': 50, 'init_stdev': 0.01, 'rank': 6, 'random_state': 42, 'l2_reg_w': 0.1, 'l2_reg_V': 0.1, 'l2_reg': 0}
#
#     kfold-type  nfeatures  train_mae  train_mae_var   val_mae  val_mae_var  \
# 13   group      165        1.86179    0.001773       2.357612  0.006144
# 140  group      165        1.86179    0.001773       2.357612  0.006144
# 141  group      165        1.86179    0.001773       2.357612  0.006144
# 142  group      165        1.86179    0.001773       2.357612  0.006144
# 143  group      165        1.86179    0.001773       2.357612  0.006144
# 144  group      165        1.86179    0.001773       2.357612  0.006144
# 145  group      165        1.86179    0.001773       2.357612  0.006144
# 146  group      165        1.86179    0.001773       2.357612  0.006144
# 147  group      165        1.86179    0.001773       2.357612  0.006144
# 148  group      165        1.86179    0.001773       2.357612  0.006144
# 149  group      165        1.86179    0.001773       2.357612  0.006144
# 150  group      165        1.86179    0.001773       2.357612  0.006144
# 151  group      165        1.86179    0.001773       2.357612  0.006144
# 152  group      165        1.86179    0.001773       2.357612  0.006144
# 153  group      165        1.86179    0.001773       2.357612  0.006144
# 154  group      165        1.86179    0.001773       2.357612  0.006144
# 155  group      165        1.86179    0.001773       2.357612  0.006144
# 156  group      165        1.86179    0.001773       2.357612  0.006144
# 157  group      165        1.86179    0.001773       2.357612  0.006144
# 158  group      165        1.86179    0.001773       2.357612  0.006144
# 159  group      165        1.86179    0.001773       2.357612  0.006144
# 160  group      165        1.86179    0.001773       2.357612  0.006144
# 139  group      165        1.86179    0.001773       2.357612  0.006144
# 161  group      165        1.86179    0.001773       2.357612  0.006144
# 138  group      165        1.86179    0.001773       2.357612  0.006144
# 136  group      165        1.86179    0.001773       2.357612  0.006144
# 115  group      165        1.86179    0.001773       2.357612  0.006144
# 116  group      165        1.86179    0.001773       2.357612  0.006144
# 117  group      165        1.86179    0.001773       2.357612  0.006144
# 118  group      165        1.86179    0.001773       2.357612  0.006144
# ..     ...      ...            ...         ...            ...       ...
# 109  group      165        1.86179    0.001773       2.357612  0.006144
# 110  group      165        1.86179    0.001773       2.357612  0.006144
# 89   group      165        1.86179    0.001773       2.357612  0.006144
# 88   group      165        1.86179    0.001773       2.357612  0.006144
# 87   group      165        1.86179    0.001773       2.357612  0.006144
# 86   group      165        1.86179    0.001773       2.357612  0.006144
# 64   group      165        1.86179    0.001773       2.357612  0.006144
# 65   group      165        1.86179    0.001773       2.357612  0.006144
# 66   group      165        1.86179    0.001773       2.357612  0.006144
# 67   group      165        1.86179    0.001773       2.357612  0.006144
# 68   group      165        1.86179    0.001773       2.357612  0.006144
# 69   group      165        1.86179    0.001773       2.357612  0.006144
# 70   group      165        1.86179    0.001773       2.357612  0.006144
# 71   group      165        1.86179    0.001773       2.357612  0.006144
# 72   group      165        1.86179    0.001773       2.357612  0.006144
# 73   group      165        1.86179    0.001773       2.357612  0.006144
# 211  group      165        1.86179    0.001773       2.357612  0.006144
# 74   group      165        1.86179    0.001773       2.357612  0.006144
# 76   group      165        1.86179    0.001773       2.357612  0.006144
# 77   group      165        1.86179    0.001773       2.357612  0.006144
# 78   group      165        1.86179    0.001773       2.357612  0.006144
# 79   group      165        1.86179    0.001773       2.357612  0.006144
# 80   group      165        1.86179    0.001773       2.357612  0.006144
# 81   group      165        1.86179    0.001773       2.357612  0.006144
# 82   group      165        1.86179    0.001773       2.357612  0.006144
# 83   group      165        1.86179    0.001773       2.357612  0.006144
# 84   group      165        1.86179    0.001773       2.357612  0.006144
# 85   group      165        1.86179    0.001773       2.357612  0.006144
# 75   group      165        1.86179    0.001773       2.357612  0.006144
# 212  group      165        1.86179    0.001773       2.357612  0.006144
#
#      mae_diff
# 13   0.495822
# 140  0.495822
# 141  0.495822
# 142  0.495822
# 143  0.495822
# 144  0.495822
# 145  0.495822
# 146  0.495822
# 147  0.495822
# 148  0.495822
# 149  0.495822
# 150  0.495822
# 151  0.495822
# 152  0.495822
# 153  0.495822
# 154  0.495822
# 155  0.495822
# 156  0.495822
# 157  0.495822
# 158  0.495822
# 159  0.495822
# 160  0.495822
# 139  0.495822
# 161  0.495822
# 138  0.495822
# 136  0.495822
# 115  0.495822
# 116  0.495822
# 117  0.495822
# 118  0.495822
# ..        ...
# 109  0.495822
# 110  0.495822
# 89   0.495822
# 88   0.495822
# 87   0.495822
# 86   0.495822
# 64   0.495822
# 65   0.495822
# 66   0.495822
# 67   0.495822
# 68   0.495822
# 69   0.495822
# 70   0.495822
# 71   0.495822
# 72   0.495822
# 73   0.495822
# 211  0.495822
# 74   0.495822
# 76   0.495822
# 77   0.495822
# 78   0.495822
# 79   0.495822
# 80   0.495822
# 81   0.495822
# 82   0.495822
# 83   0.495822
# 84   0.495822
# 85   0.495822
# 75   0.495822
# 212  0.495822
#
# [200 rows x 9 columns]

# %%
df_submit = pd.DataFrame()
df_submit['time_to_failure'] = np.mean(df_test_pred.drop(columns=['index']).values, axis=1)
df_submit['seg_id'] = df_test_pred['index']
df_submit.to_csv('submission.csv', index=False)

# %%
df_trial.to_pickle('../trial/fm.pkl')
